# %%
import pandas as pd
movies= pd.read_csv('Movie-Assignment-Data-1.csv')

# %%
movies.shape
# Out:
# (5043, 28)

# %%
movies.head(5)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movies.tail(3)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                 genres  ...  \
# 5040                     0.0      NaN  Drama|Horror|Thriller  ...
# 5041                   946.0  10443.0   Comedy|Drama|Romance  ...
# 5042                    86.0  85222.0            Documentary  ...
#
#      num_user_for_reviews language  country  content_rating  budget  \
# 5040                  3.0  English      USA             NaN  1400.0
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
nullcount=movies.isnull().sum()
nullcount
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
null_percent=((nullcount/len(movies))*100)
afterroundoff=round(null_percent,2)
afterroundoff
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.28
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %%
drop_column = movies.drop(columns=[
    "color", "director_facebook_likes", "actor_1_facebook_likes",
    "actor_2_facebook_likes", "actor_3_facebook_likes", "actor_2_name",
    "cast_total_facebook_likes", "actor_3_name", "duration",
    "facenumber_in_poster", "content_rating", "country",
    "movie_imdb_link", "aspect_ratio", "plot_keywords"
],inplace=True)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
null_percent = movies.isnull().mean() * 100
highnullpercentcol= null_percent[null_percent>5].index.tolist()
movies= movies.dropna(subset=highnullpercentcol)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
total_cols= len(movies.columns)
max_nan_allowed= 5
reqdvalidvalue= total_cols-max_nan_allowed
drop_row_of_morethan5nan= movies.dropna(thresh=reqdvalidvalue)
drop_row_of_morethan5nan
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
movies['language'].fillna('English')
# Out:
# 0       English
# 1       English
# 2       English
# 3       English
# 5       English
#          ...
# 5033    English
# 5034    English
# 5035    Spanish
# 5037    English
# 5042    English
# Name: language, Length: 3891, dtype: object

# %%
current_rows= movies.shape[0]
original_rows=5043
rowsretainedpercent= (current_rows/original_rows)*100
rowsretainedpercent
# Out:
# 77.15645449137418

# %%
movies.shape
# Out:
# (3891, 13)

# %%
movies.loc[:,'budget']= movies['budget']/1000000
movies.loc[:,'gross']= movies['gross']/1000000
movies[['budget','gross']].head()
# Out:
#    budget       gross
# 0   237.0  760.505847
# 1   300.0  309.404152
# 2   245.0  200.074175
# 3   250.0  448.130642
# 5   263.7   73.058679

# %%
movies.loc[:,'profit']= movies['gross']-movies['budget']
movies['profit']
# Out:
# /tmp/ipykernel_1048/2057474162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.loc[:,'profit']= movies['gross']-movies['budget']
# 0       523.505847
# 1         9.404152
# 2       -44.925825
# 3       198.130642
# 5      -190.641321
#            ...
# 5033      0.417760
# 5034      0.063071
# 5035      2.033920
# 5037     -0.004416
# 5042      0.084122
# Name: profit, Length: 3891, dtype: float64

# %%
movies_sorted=movies.sort_values(by= 'profit', ascending=False)
movies_sorted
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 29     Colin Trevorrow                   644.0  652.177271
# 26       James Cameron                   315.0  658.672302
# 3024      George Lucas                   282.0  460.935665
# 3080  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2334   Katsuhiro Ôtomo                   105.0    0.410388
# 2323    Hayao Miyazaki                   174.0    2.298191
# 3005      Lajos Koltai                    73.0    0.195888
# 3859    Chan-wook Park                   202.0    0.211667
# 2988      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
top10= movies_sorted.head(10)
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 17          Joss Whedon                   703.0  623.279547
# 794         Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %%
movies= movies.drop_duplicates()
movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
movies_sorted= movies.sort_values(by='profit',ascending=False)
topten= movies_sorted.head(10)
topten
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
# 439           Gary Ross                   673.0  407.999255
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %%
topten.duplicated().sum()
# Out:
# np.int64(0)

# %%
filtered_movies= movies[movies['num_voted_users']>=25000]
filtered_movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 4977    Morgan Spurlock                   193.0   11.529368
# 5008        Kevin Smith                   136.0    3.151130
# 5012         David Ayer                   233.0   10.499968
# 5033      Shane Carruth                   143.0    0.424760
# 5035   Robert Rodriguez                    56.0    2.040920
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
sorted_movies= filtered_movies.sort_values(by='imdb_score',ascending=False)
sorted_movies
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 4498          Sergio Leone                   181.0    6.100000
# ...                    ...                     ...         ...
# 2313              Uwe Boll                   148.0    5.132655
# 319      Lawrence Guterman                    78.0   17.010646
# 2268       Jason Friedberg                   111.0   14.174654
# 2295             Bob Clark                    32.0    9.109322
# 2834            Jon M. Chu                    84.0   73.000942
#
#                            genres               actor_1_name  \
# 1937                  Crime|Drama             Morgan Freeman
# 3466                  Crime|Drama                  Al Pacino
# ...

# %%
IMDb_Top_250= sorted_movies.head(250).copy()
IMDb_Top_250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 4498          Sergio Leone                   181.0    6.100000
# ...                    ...                     ...         ...
# 1884        Brian De Palma                   123.0   76.270454
# 1813        Philip Kaufman                    80.0   21.500000
# 1748          F. Gary Gray                   349.0  161.029270
# 1871          Pierre Morel                   309.0  145.000989
# 1807           John Landis                   125.0   54.200000
#
#                                    genres    actor_1_name  \
# 1937                          Crime|Drama  Morgan Freeman
# 3466                          Crime|Drama       Al Pacino
# ...

# %%
IMDb_Top_250['Rank']= range(1, len(IMDb_Top_250)+1)
IMDb_Top_250.reset_index(drop=True,inplace=True)
IMDb_Top_250
# Out:
#             director_name  num_critic_for_reviews       gross  \
# 0          Frank Darabont                   199.0   28.341469
# 1    Francis Ford Coppola                   208.0  134.821952
# 2    Francis Ford Coppola                   149.0   57.300000
# 3       Christopher Nolan                   645.0  533.316061
# 4            Sergio Leone                   181.0    6.100000
# ..                    ...                     ...         ...
# 245        Brian De Palma                   123.0   76.270454
# 246        Philip Kaufman                    80.0   21.500000
# 247          F. Gary Gray                   349.0  161.029270
# 248          Pierre Morel                   309.0  145.000989
# 249           John Landis                   125.0   54.200000
#
#                                   genres    actor_1_name  \
# 0                            Crime|Drama  Morgan Freeman
# 1                            Crime|Drama       Al Pacino
# ...

# %%
Top_Foreign_Lang_Film= IMDb_Top_250[IMDb_Top_250['language']!='English'].copy()
Top_Foreign_Lang_Film
# Out:
#                         director_name  num_critic_for_reviews       gross  \
# 4                        Sergio Leone                   181.0    6.100000
# 15                     Akira Kurosawa                   153.0    0.269061
# 16                 Fernando Meirelles                   214.0    7.563397
# 24                     Hayao Miyazaki                   246.0   10.049886
# 30   Florian Henckel von Donnersmarck                   215.0   11.284657
# 39                       Majid Majidi                    46.0    0.925402
# 49                     S.S. Rajamouli                    44.0    6.498000
# 50                 Jean-Pierre Jeunet                   242.0   33.201661
# 51                     Hayao Miyazaki                   174.0    2.298191
# 54                  Wolfgang Petersen                    96.0   11.433134
# 55                     Chan-wook Park                   305.0    2.181290
# 59                     Asghar Farhadi                   354.0    7.098492
# ...

# %%
director_rating= movies.groupby('director_name')['imdb_score'].mean().reset_index()
director_rating
# Out:
#            director_name  imdb_score
# 0        Aaron Schneider       7.100
# 1          Aaron Seltzer       2.700
# 2           Abel Ferrara       6.600
# 3           Adam Carolla       6.100
# 4          Adam Goldberg       5.400
# ...                  ...         ...
# 1748         Zack Snyder       7.175
# 1749            Zak Penn       6.600
# 1750      Zal Batmanglij       6.900
# 1751  Álex de la Iglesia       6.100
# 1752    Émile Gaudreault       6.700
#
# [1753 rows x 2 columns]

# %%
director_sorted= director_rating.sort_values(by='imdb_score', ascending=False).head(10)
director_sorted
# Out:
#           director_name  imdb_score
# 1675          Tony Kaye    8.600000
# 216     Charles Chaplin    8.600000
# 1440         Ron Fricke    8.500000
# 45     Alfred Hitchcock    8.500000
# 1017       Majid Majidi    8.500000
# 302     Damien Chazelle    8.500000
# 1498       Sergio Leone    8.433333
# 260   Christopher Nolan    8.425000
# 1371   Richard Marquand    8.400000
# 1467     S.S. Rajamouli    8.400000

# %%
top10director= director_sorted.head(10).copy()
top10director.rename(columns={'imdb_score': 'mean_imdb_score'}, inplace=True)
top10director
# Out:
#           director_name  mean_imdb_score
# 1675          Tony Kaye         8.600000
# 216     Charles Chaplin         8.600000
# 1440         Ron Fricke         8.500000
# 45     Alfred Hitchcock         8.500000
# 1017       Majid Majidi         8.500000
# 302     Damien Chazelle         8.500000
# 1498       Sergio Leone         8.433333
# 260   Christopher Nolan         8.425000
# 1371   Richard Marquand         8.400000
# 1467     S.S. Rajamouli         8.400000
